# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches
import numpy as np
from matplotlib.gridspec import GridSpec
import matplotlib as mpl
from funciones_data_visualization import *
from variables_data_visualization import *
from pylab import rcParams
import matplotlib.colors as mcolors

# %%
from funciones_data_visualization import *
from variables_data_visualization import *

# %%
#f9f1e6
#ee9173
#8b9cb2
#6e6763

# %%
#c5c5c5 - gris
#f54939 - rojo
#a1a1a1 - gris oscuro
#2018c2 - azul
#838383 - gris más oscuro

# %%
from matplotlib import font_manager
font_manager.findSystemFonts(fontpaths=None, fontext="ttf")
font_manager.findfont("PP Neue Montreal")
# Out:
# '/Users/laurabarreda/Library/Fonts/PPNeueMontreal-Book.otf'

# %%
enmax_palette = ["#c5c5c5", "#f54939", "#2018c2", '#a1a1a1', '#838383']
color_codes_wanted = ['grey1', 'red', 'blue', 'grey2', 'grey3']
c = lambda x: enmax_palette[color_codes_wanted.index(x)]
# csfont = {'fontname':'PP Neue Montreal'}
mpl.rcParams['font.size'] = 15
mpl.rcParams['font.sans-serif'] = 'PP Neue Montreal'

# %%
def pie_plot_general(data1, data2, labels_pie, title):
    '''
    Funcion que crea un pieplot único
    '''
    csfont = {'fontname':'PP Neue Montreal'}
    fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(13, 8))
    ax.set_facecolor(c("grey1"))
    data = [data1, data2]
    colors = [c('red'), c('grey2')]
    pie_plot = plt.pie(data, labels = None, colors = colors, autopct='%.0f%%', wedgeprops={"edgecolor":"white"})
    plt.legend(labels=labels_pie,loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white')
    plt.title(title, pad=30, fontsize = 15, **csfont)
    return pie_plot

# %%
europe_worker_force_total
# Out:
#                                              Country  2019_total  2019_males  \
# 0          European Union - 27 countries (from 2020)    167909.5     87324.7
# 1          European Union - 28 countries (2013-2020)    194819.3    100849.0
# 2          European Union - 15 countries (1995-2004)    156592.5     80508.4
# 3              Euro area - 19 countries  (from 2015)    128728.8     66505.6
# 4                                            Belgium      4157.1      2124.5
# 5                                           Bulgaria      2801.1      1470.3
# 6                                            Czechia      4331.6      2312.9
# 7                                            Denmark      2581.9      1323.0
# 8   Germany (until 1990 former territory of the FRG)     37985.4     19751.9
# 9                                            Estonia       571.5       285.0
# 10                                           Ireland      1976.4       996.5
# ...

# %%
figura = pie_plot_general(europe_worker_force_total.iloc[0]['2022_females'], europe_worker_force_total.iloc[0]['2022_males'], ['Female', 'Male'], 'Work force distribution in Europe by gender (2022)');

# %%
year = [2019,2020,2021,2022]
female = [80584.80, 78776.35, 78444.70, 81267.50]
male = [87324.7, 85480.5, 84317.1, 87124.5]

x_axis = np.arange(len(year))
fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(13, 8), edgecolor='white')
ax.set_facecolor(c("grey1"))

plt.bar(x_axis -0.2, female, width=0.4, label = 'Female', color=c('red'), edgecolor='white');
plt.bar(x_axis +0.2, male, width=0.4, label = 'Male', color=c('grey2'), edgecolor='white');

# plt.grid(color='white', linestyle='-.', linewidth=.4)
plt.grid(visible=False)
plt.xticks(x_axis, year);
plt.title('Work force distributin in Europe by gender from 2019 until 2022', pad=30, fontsize = 15);
plt.legend(labels=['Female', 'Male'],loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white');
plt.show()

# %%
# bar_doble(distribution_men_women_total_work_force_europe, ['male', 'female'], 'Work force distributin in Europe by gender from 2019 until 2022');

# %%
def pie_plot_inside_grid4(data1, data2,ax1, ax2):
    '''
    Función que crea un pie plot preparado para estar dentro de un grid de 4x4
    '''
    csfont = {'fontname':'PP Neue Montreal'}

    data = [data1, data2]
    colors = [c('red'), c('grey2')]
    pie_plot_total = axs[ax1, ax2].pie(data, colors = colors, autopct='%.0f%%', wedgeprops={"edgecolor":"white"})
    return pie_plot_total

# %%
dataframe_worker_force_europe_2022
# Out:
#    managers  professionals  technicians  support  gender
# 0    2632.5        20558.2      14747.1  12686.4  Female
# 1    4093.1        16181.4      13699.0   6393.6    Male

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8), facecolor=c("grey1"))
labels = ['Female', 'Male']
ax.set_facecolor(c("grey1"))
pie_plot_inside_grid4(dataframe_worker_force_europe_2022.iloc[0]['managers'], dataframe_worker_force_europe_2022.iloc[1]['managers'], 0, 0);
pie_plot_inside_grid4(dataframe_worker_force_europe_2022.iloc[0]['professionals'], dataframe_worker_force_europe_2022.iloc[1]['professionals'], 0, 1);
pie_plot_inside_grid4(dataframe_worker_force_europe_2022.iloc[0]['technicians'], dataframe_worker_force_europe_2022.iloc[1]['technicians'], 1, 0);
pie_plot_inside_grid4(dataframe_worker_force_europe_2022.iloc[0]['support'], dataframe_worker_force_europe_2022.iloc[1]['support'], 1, 1);
axs[0, 0].set_title("Managers")
axs[0, 1].set_title("Professionals")
axs[1, 0].set_title("Technicians")
axs[1, 1].set_title("Support")
plt.figlegend(labels=labels,loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white');
plt.suptitle('Work force distribution in Europe by gender and profession type (2022)')
# Out:
# Text(0.5, 0.98, 'Work force distribution in Europe by gender and profession type (2022)')

# %%
def line_plot_comparison_years(dataframe, valor_x, valor_y, valor_hue, ax_number, title):
    colors = [c('red'), c('grey2')]
    sns.set(rc={'axes.facecolor':c('grey1')})
    sns.set_palette(sns.color_palette(colors))
    line_plot_comparison = sns.lineplot(data=dataframe, x=valor_x, y=valor_y, hue=valor_hue, ax=ax_number, linewidth=2).set(title=title)
    return line_plot_comparison

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, sharey=True, figsize=(13, 7), facecolor=c("grey1"))
ax.set_facecolor(c("grey1"))
colors = [c('red'), c('grey2')]
sns.set_palette(sns.color_palette(colors))

line_plot_comparison_years(comparison_dataframe_años, 'años', "numero_managers", 'gender', ax1, 'Managers');
plt.grid(visible=False)
plt.legend([],[], frameon=False)
line_plot_comparison_years(comparison_dataframe_años, 'años', "numero_professionals", 'gender', ax2, 'Professionals');
line_plot_comparison_years(comparison_dataframe_años, 'años', "numero_technicians", 'gender', ax3, 'Technicians');
line_plot_comparison_years(comparison_dataframe_años, 'años', "numero_support", 'gender', ax4, 'Support');
plt.grid(color='white', linestyle='-.', linewidth=.2)
plt.legend([],[], frameon=False)
plt.figlegend(labels=labels,loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white');
plt.suptitle('Evolution of the work force distribution in Europe by gender and profession type')
# Out:
# Text(0.5, 0.98, 'Evolution of the work force distribution in Europe by gender and profession type')

# %%
boards_world_percentage = pd.read_csv('paises_seleccionados_board_world_percentage.csv')

# %%
# Reorder it following the values of the first value:
boards_world_percentage = boards_world_percentage.sort_values(by='females')
my_range=range(1,len(boards_world_percentage.index)+1)
 
# The horizontal plot is made using the hline function
fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(15, 11))
ax.set_facecolor(c("grey1"))


plt.scatter(boards_world_percentage['females'], my_range, color=c('red'), alpha=1, label='value1', edgecolor='white', s=300)
plt.scatter(boards_world_percentage['males'], my_range, color=c("grey2"), alpha=1 , label='value2', edgecolor='white', s=300)
plt.hlines(y=my_range, xmin=boards_world_percentage['males'], xmax=boards_world_percentage['females'], color='white', alpha=1)
plt.figlegend(labels=labels,loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white');
 
# Add title and axis names
plt.yticks(my_range, boards_world_percentage['Country'])
plt.title("Percentage gap between women and men in boards of the largest publicly listed companies", pad=30)
plt.xlabel('Percentage gap')
plt.ylabel('Country')
plt.grid(visible=False)
# rcParams['figure.figsize'] = 15, 9

# Show the graph
plt.show()

# %%
managers_world_percentage_max_min = pd.read_csv('paises_seleccionados_managers_world_percentage.csv')

# %%
country_list = ["Korea", "Estonia", "Russia", "Japan", "Brazil", "India", "Poland", "United States", "Ireland", "Spain", "Canada", "South Africa", "Australia", "Germany", "United Kingdom", "Sweden", "France", "Iceland"]

# %%
managers_world_percentage_max_min['Country'] = pd.Categorical(managers_world_percentage_max_min['Country'], country_list)

# %%
# Reorder it following the values of the first value:
managers_world_percentage_max_min = managers_world_percentage_max_min.sort_values(by='Country')
my_range=range(1,len(managers_world_percentage_max_min.index)+1)
 
# The horizontal plot is made using the hline function
fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(15, 11))
ax.set_facecolor(c("grey1"))


plt.scatter(managers_world_percentage_max_min['females'], my_range, color=c('red'), alpha=1, label='value1', edgecolor='white', s=300)
plt.scatter(managers_world_percentage_max_min['males'], my_range, color=c("grey2"), alpha=1 , label='value2', edgecolor='white', s=300)
plt.hlines(y=my_range, xmin=managers_world_percentage_max_min['males'], xmax=managers_world_percentage_max_min['females'], color='white', alpha=1)
plt.figlegend(labels=labels,loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white');
 
# Add title and axis names
plt.yticks(my_range, managers_world_percentage_max_min['Country'])
plt.title("Percentage gap between women and men in boards of the largest publicly listed companies", pad=30)
plt.xlabel('Percentage gap')
plt.ylabel('Country')
plt.grid(visible=False)
# rcParams['figure.figsize'] = 15, 9

# Show the graph
plt.show()

# %%
boards_world_percentage_max_min = pd.read_csv('women_board_percentage_max_min_world.csv')

# %%
fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(19, 12))
ax.set_facecolor(c("grey1"))

colors = ['white', 'blue', '#069bab', '#f35957', 'red']
sns.set_palette(sns.color_palette(colors))

sns.lineplot(x='Time', y='Value', hue='Country', 
             data=boards_world_percentage_max_min, ci=300, linewidth=2)
plt.legend(loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white');
plt.grid(visible=False)
plt.title("Evolution of the ration women/men in the countries with most and least equality", pad=30)
# Out:
# Text(0.5, 1.0, 'Evolution of the ration women/men in the countries with most and least equality')

# %%
managers_world_percentage_max_min = pd.read_csv('women_managers_percentage_max_min_world.csv')

# %%
fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(15, 9))
ax.set_facecolor(c("grey1"))


colors = ['white', 'blue', '#069bab', '#f35957', 'red']
sns.set_palette(sns.color_palette(colors))

sns.lineplot(x='Time', y='Value', hue='Country', 
             data=managers_world_percentage_max_min, linewidth=2)
plt.legend(loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white');
plt.grid(visible=False)
plt.title("Evolution of the ration women/men managers in the countries with most and least equality", pad=30)
# Out:
# Text(0.5, 1.0, 'Evolution of the ration women/men managers in the countries with most and least equality')

# %%
all_women_boards_worldwide_percentage = pd.read_csv('all_women_boards_worldwide_percentage.csv')

# %%
fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(15, 9))
ax.set_facecolor(c("grey1"))

colors = [c('red'), '#c81200', '#eb3928', c('red'), '#d13a2d', '#df766b', '#e79289']
sns.set_palette(sns.color_palette('Greys'))

sns.lineplot(x='Time', y='Value', hue='Country', 
             data=all_women_boards_worldwide_percentage, linewidth=2)
plt.legend(loc = 2, bbox_to_anchor = (1,1), prop={'size': 9}, facecolor=c('grey1'), edgecolor='white');
plt.grid(visible=False)
plt.title("Evolution of the ration women/men in boards worldwide", pad=30)
# Out:
# Text(0.5, 1.0, 'Evolution of the ration women/men in boards worldwide')

# %%
all_women_managers_percentage_worldwide = pd.read_csv('all_women_managers_percentage_worldwide.csv')

# %%
fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(15, 9))
ax.set_facecolor(c("grey1"))

colors = ['#c81200', '#c81200', '#eb3928', c('red'), '#d13a2d', '#df766b', '#e79289']
sns.set_palette(sns.color_palette(colors))

sns.lineplot(x='Time', y='Value', hue='Country', 
             data=all_women_managers_percentage_worldwide)
plt.legend(loc = 2, bbox_to_anchor = (1,1), prop={'size': 9}, facecolor=c('grey1'), edgecolor='white');
plt.grid(color='white', linestyle='-.', linewidth=.2)
plt.title("Evolution of the ration women/men managers worldwide", pad=30)
# Out:
# Text(0.5, 1.0, 'Evolution of the ration women/men managers worldwide')

# %%
women_boards_europe_women_percentage = pd.read_csv('women_boards_europe_women_percentage.csv')

# %%
women_boards_europe_women_percentage = women_boards_europe_women_percentage.iloc[: , 1:]
women_boards_europe_women_percentage
# Out:
#         year         country  number                       position  \
# 0       2012         Austria     0.0  CEO (Chief Executive Officer)
# 1       2013         Austria     0.0  CEO (Chief Executive Officer)
# 2       2013         Austria     0.0  CEO (Chief Executive Officer)
# 3       2014         Austria     0.0  CEO (Chief Executive Officer)
# 4       2014         Austria     0.0  CEO (Chief Executive Officer)
# ...      ...             ...     ...                            ...
# 134055  2020  United Kingdom     8.0                      President
# 134056  2020  United Kingdom     8.0                      President
# 134057  2021  United Kingdom    10.0                      President
# 134058  2021  United Kingdom    16.0                      President
# 134059  2022  United Kingdom    16.0                      President
#
#        position init    sex  \
# 0                CEO  Women
# 1                CEO  Women
# 2                CEO  Women
# 3                CEO  Women
# ...

# %%
women_boards_europe_women_percentage_nace_1 = women_boards_europe_women_percentage.loc[women_boards_europe_women_percentage['nace'] == 'C, E & F (Mining & quarrying; electricity, gas and water; construction)']
women_boards_europe_women_percentage_nace_1 = women_boards_europe_women_percentage_nace_1[['year', 'number', 'Total', 'percentage']]
women_boards_europe_women_percentage_nace_1 = women_boards_europe_women_percentage_nace_1.groupby(['year'], as_index=False)[['number', 'Total']].sum()
percentage = 100 * women_boards_europe_women_percentage_nace_1["number"] / women_boards_europe_women_percentage_nace_1["Total"]
women_boards_europe_women_percentage_nace_1["percentage"] = percentage
women_boards_europe_women_percentage_nace_1 = women_boards_europe_women_percentage_nace_1[['year', 'percentage']]

# %%
women_boards_europe_women_percentage_nace_2 = women_boards_europe_women_percentage.loc[women_boards_europe_women_percentage['nace'] == 'D Manufacturing']
women_boards_europe_women_percentage_nace_2 = women_boards_europe_women_percentage_nace_2[['year', 'number', 'Total', 'percentage']]
women_boards_europe_women_percentage_nace_2 = women_boards_europe_women_percentage_nace_2.groupby(['year'], as_index=False)[['number', 'Total']].sum()
percentage = 100 * women_boards_europe_women_percentage_nace_2["number"] / women_boards_europe_women_percentage_nace_2["Total"]
women_boards_europe_women_percentage_nace_2["percentage"] = percentage
women_boards_europe_women_percentage_nace_2 = women_boards_europe_women_percentage_nace_2[['year', 'percentage']]

# %%
women_boards_europe_women_percentage_nace_3 = women_boards_europe_women_percentage.loc[women_boards_europe_women_percentage['nace'] == 'E Electricity, gas and water supply']
women_boards_europe_women_percentage_nace_3 = women_boards_europe_women_percentage_nace_3[['year', 'number', 'Total', 'percentage']]
women_boards_europe_women_percentage_nace_3 = women_boards_europe_women_percentage_nace_3.groupby(['year'], as_index=False)[['number', 'Total']].sum()
percentage = 100 * women_boards_europe_women_percentage_nace_3["number"] / women_boards_europe_women_percentage_nace_3["Total"]
women_boards_europe_women_percentage_nace_3["percentage"] = percentage
women_boards_europe_women_percentage_nace_3 = women_boards_europe_women_percentage_nace_3[['year', 'percentage']]

# %%
women_boards_europe_women_percentage_nace_4 = women_boards_europe_women_percentage.loc[women_boards_europe_women_percentage['nace'] == 'F Construction']
women_boards_europe_women_percentage_nace_4 = women_boards_europe_women_percentage_nace_4[['year', 'number', 'Total', 'percentage']]
women_boards_europe_women_percentage_nace_4 = women_boards_europe_women_percentage_nace_4.groupby(['year'], as_index=False)[['number', 'Total']].sum()
percentage = 100 * women_boards_europe_women_percentage_nace_4["number"] / women_boards_europe_women_percentage_nace_4["Total"]
women_boards_europe_women_percentage_nace_4["percentage"] = percentage
women_boards_europe_women_percentage_nace_4 = women_boards_europe_women_percentage_nace_4[['year', 'percentage']]

# %%
women_boards_europe_women_percentage_nace_5 = women_boards_europe_women_percentage.loc[women_boards_europe_women_percentage['nace'] == 'G, H & I (Wholesale/retail, vehicle repair; hotels/restaurants; transport, storage & communication)']
women_boards_europe_women_percentage_nace_5 = women_boards_europe_women_percentage_nace_5[['year', 'number', 'Total', 'percentage']]
women_boards_europe_women_percentage_nace_5 = women_boards_europe_women_percentage_nace_5.groupby(['year'], as_index=False)[['number', 'Total']].sum()
percentage = 100 * women_boards_europe_women_percentage_nace_5["number"] / women_boards_europe_women_percentage_nace_5["Total"]
women_boards_europe_women_percentage_nace_5["percentage"] = percentage
women_boards_europe_women_percentage_nace_5 = women_boards_europe_women_percentage_nace_5[['year', 'percentage']]

# %%
women_boards_europe_women_percentage_nace_6 = women_boards_europe_women_percentage.loc[women_boards_europe_women_percentage['nace'] == 'H Hotels and restaurants']
women_boards_europe_women_percentage_nace_6 = women_boards_europe_women_percentage_nace_6[['year', 'number', 'Total', 'percentage']]
women_boards_europe_women_percentage_nace_6 = women_boards_europe_women_percentage_nace_6.groupby(['year'], as_index=False)[['number', 'Total']].sum()
percentage = 100 * women_boards_europe_women_percentage_nace_6["number"] / women_boards_europe_women_percentage_nace_6["Total"]
women_boards_europe_women_percentage_nace_6["percentage"] = percentage
women_boards_europe_women_percentage_nace_6 = women_boards_europe_women_percentage_nace_6[['year', 'percentage']]

# %%
women_boards_europe_women_percentage_nace_7 = women_boards_europe_women_percentage.loc[women_boards_europe_women_percentage['nace'] == 'I Transport, storage and communication']
women_boards_europe_women_percentage_nace_7 = women_boards_europe_women_percentage_nace_7[['year', 'number', 'Total', 'percentage']]
women_boards_europe_women_percentage_nace_7 = women_boards_europe_women_percentage_nace_7.groupby(['year'], as_index=False)[['number', 'Total']].sum()
percentage = 100 * women_boards_europe_women_percentage_nace_7["number"] / women_boards_europe_women_percentage_nace_7["Total"]
women_boards_europe_women_percentage_nace_7["percentage"] = percentage
women_boards_europe_women_percentage_nace_7 = women_boards_europe_women_percentage_nace_7[['year', 'percentage']]

# %%
women_boards_europe_women_percentage_nace_8 = women_boards_europe_women_percentage.loc[women_boards_europe_women_percentage['nace'] == 'J Financial intermediation']
women_boards_europe_women_percentage_nace_8 = women_boards_europe_women_percentage_nace_8[['year', 'number', 'Total', 'percentage']]
women_boards_europe_women_percentage_nace_8 = women_boards_europe_women_percentage_nace_8.groupby(['year'], as_index=False)[['number', 'Total']].sum()
percentage = 100 * women_boards_europe_women_percentage_nace_8["number"] / women_boards_europe_women_percentage_nace_8["Total"]
women_boards_europe_women_percentage_nace_8["percentage"] = percentage
women_boards_europe_women_percentage_nace_8 = women_boards_europe_women_percentage_nace_8[['year', 'percentage']]

# %%
women_boards_europe_women_percentage_nace_9 = women_boards_europe_women_percentage.loc[women_boards_europe_women_percentage['nace'] == 'K Real estate, renting and business activities, consulting']
women_boards_europe_women_percentage_nace_9 = women_boards_europe_women_percentage_nace_9[['year', 'number', 'Total', 'percentage']]
women_boards_europe_women_percentage_nace_9 = women_boards_europe_women_percentage_nace_9.groupby(['year'], as_index=False)[['number', 'Total']].sum()
percentage = 100 * women_boards_europe_women_percentage_nace_9["number"] / women_boards_europe_women_percentage_nace_9["Total"]
women_boards_europe_women_percentage_nace_9["percentage"] = percentage
women_boards_europe_women_percentage_nace_9 = women_boards_europe_women_percentage_nace_9[['year', 'percentage']]

# %%
women_boards_europe_women_percentage_nace_10 = women_boards_europe_women_percentage.loc[women_boards_europe_women_percentage['nace'] == 'A, B, K-Q & Unknown - aggregate of sectors with few large companies']
women_boards_europe_women_percentage_nace_10 = women_boards_europe_women_percentage_nace_10[['year', 'number', 'Total', 'percentage']]
women_boards_europe_women_percentage_nace_10 = women_boards_europe_women_percentage_nace_10.groupby(['year'], as_index=False)[['number', 'Total']].sum()
percentage = 100 * women_boards_europe_women_percentage_nace_10["number"] / women_boards_europe_women_percentage_nace_10["Total"]
women_boards_europe_women_percentage_nace_10["percentage"] = percentage
women_boards_europe_women_percentage_nace_10 = women_boards_europe_women_percentage_nace_10[['year', 'percentage']]

# %%
fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(15, 10))
ax.set_facecolor(c("grey1"))
colors = ['#c81200', '#c81200', '#eb3928', c('red'), '#d13a2d', '#df766b', '#e79289']
sns.set_palette(sns.color_palette(colors))
plt.stackplot(women_boards_europe_women_percentage_nace_1.year, women_boards_europe_women_percentage_nace_1.percentage, women_boards_europe_women_percentage_nace_2.percentage, women_boards_europe_women_percentage_nace_3.percentage, women_boards_europe_women_percentage_nace_4.percentage, women_boards_europe_women_percentage_nace_5.percentage, women_boards_europe_women_percentage_nace_6.percentage, women_boards_europe_women_percentage_nace_7.percentage, women_boards_europe_women_percentage_nace_8.percentage, women_boards_europe_women_percentage_nace_9.percentage, women_boards_europe_women_percentage_nace_10.percentage);
plt.legend(loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white', labels=['Mining, electricity, gas and water', 'Manufacturing', 'Electricity, gas and water supply', 'Construction', 'Wholesale/retail, vehicle repair; hotels/restaurants; transport', 'Hotels and restaurants', 'Transport, storage and communication', 'Financial intermediation', 'Real estate, renting and business activities, consulting', 'aggregate of sectors with few large companies']);
plt.grid(visible=False)
plt.title("Evolution of the percentage of women in the boards of the largest companies in Europe by sectors", pad=30)
# Out:
# Text(0.5, 1.0, 'Evolution of the percentage of women in the boards of the largest companies in Europe by sectors')

# %%
# import matplotlib.patches as mpatches

# # load dataset
# tips = sns.load_dataset("tips")

# # set the figure size
# plt.figure(figsize=(14, 14))

# # from raw value to percentage
# total = tips.groupby('day')['total_bill'].sum().reset_index()
# smoker = tips[tips.smoker=='Yes'].groupby('day')['total_bill'].sum().reset_index()
# smoker['total_bill'] = [i / j * 100 for i,j in zip(smoker['total_bill'], total['total_bill'])]
# total['total_bill'] = [i / j * 100 for i,j in zip(total['total_bill'], total['total_bill'])]

# # bar chart 1 -> top bars (group of 'smoker=No')
# bar1 = sns.barplot(x="day",  y="total_bill", data=total, color='darkblue')

# # bar chart 2 -> bottom bars (group of 'smoker=Yes')
# bar2 = sns.barplot(x="day", y="total_bill", data=smoker, color='lightblue')

# # add legend
# top_bar = mpatches.Patch(color='darkblue', label='smoker = No')
# bottom_bar = mpatches.Patch(color='lightblue', label='smoker = Yes')
# plt.legend(handles=[top_bar, bottom_bar])

# # show the graph
# plt.show()

# %%
women_total_new = pd.read_csv('women_total_new.csv')
ibex_35_total = pd.read_csv('ibex_total_new.csv')
over_500_total = pd.read_csv('over_500_new.csv')
under_500_total = pd.read_csv('under_500_total_new.csv')

# %%
women_total_new = women_total_new[['2017 %', '2021 %']]
ibex_35_total = ibex_35_total[['2017 %', '2021 %']]
over_500_total = over_500_total[['2017 %', '2021 %']]
under_500_total = under_500_total[['2017 %', '2021 %']]

# %%
women_total_new_dict = {'2017 %' : 0.811,
                        '2021 %' : 0.7074}
women_total_new = women_total_new.append(women_total_new_dict, ignore_index = True)
women_total_new
# Out:
#    2017 %  2021 %
# 0   0.189  0.2926
# 1   0.811  0.7074

# %%
def percentage_change(col1,col2):
    return ((col2 - col1) / col1) * 100

# %%
women_total_new['percentage_growth'] = percentage_change(women_total_new['2017 %'],women_total_new['2021 %'])    
women_total_new
# Out:
#    2017 %  2021 %  percentage_growth
# 0   0.189  0.2926          54.814815
# 1   0.811  0.7074         -12.774353

# %%
ibex_35_total_dict = {'2017 %' : 0.7721,
                        '2021 %' : 0.658}
ibex_35_total_new = ibex_35_total.append(ibex_35_total_dict, ignore_index = True)

# %%
ibex_35_total_new['percentage_growth'] = percentage_change(ibex_35_total_new['2017 %'],ibex_35_total_new['2021 %'])    
ibex_35_total_new
# Out:
#    2017 %  2021 %  percentage_growth
# 0  0.2279   0.342          50.065818
# 1  0.7721   0.658         -14.777879

# %%
over_500_total['2017 %'][0] = '0.184'
over_500_total_dict = {'2017 %' : 0.816,
                        '2021 %' : 0.7183}
over_500_total_new = over_500_total.append(over_500_total_dict, ignore_index = True)

# %%
over_500_total_new['percentage_growth'] = percentage_change(over_500_total_new['2017 %'],over_500_total_new['2021 %'])    
over_500_total_new
# Out:
#    2017 %  2021 %  percentage_growth
# 0   0.184  0.2817          53.097826
# 1   0.816  0.7183         -11.973039

# %%
under_500_total['2017 %'][0] = '0.156'
under_500_total_dict = {'2017 %' : 0.844,
                        '2021 %' : 0.7481}
under_500_total_new = under_500_total.append(under_500_total_dict, ignore_index = True)

# %%
under_500_total_new['percentage_growth'] = percentage_change(under_500_total_new['2017 %'],under_500_total_new['2021 %'])    
under_500_total_new
# Out:
#    2017 %  2021 %  percentage_growth
# 0   0.156  0.2519          61.474359
# 1   0.844  0.7481         -11.362559

# %%
def pie_plot_inside_grid4(data1, data2, ax_number, title):
    '''
    Función que crea un pie plot preparado para estar dentro de un grid de 4x4
    '''
    csfont = {'fontname':'PP Neue Montreal'}

    data = [data1, data2]
    colors = [c('red'), c('grey2')]
    pie_plot_total = ax_number.pie(data, colors = colors, autopct='%.0f%%', wedgeprops={"edgecolor":"white"})
    return pie_plot_total

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(ncols=4, figsize=(30, 10), facecolor=c("grey1"))
labels = ['Female', 'Male']
ax.set_facecolor(c("grey1"))
pie_plot_inside_grid4(women_total_new['2017 %'][0], women_total_new['2017 %'][1], ax1, 'hola');
pie_plot_inside_grid4(ibex_35_total_new['2017 %'][0], ibex_35_total_new['2017 %'][1], ax2, 'hola');
pie_plot_inside_grid4(over_500_total_new['2017 %'][0], over_500_total_new['2017 %'][1], ax3, 'hola');
pie_plot_inside_grid4(under_500_total_new['2017 %'][0], under_500_total_new['2017 %'][1], ax4, 'hola');
ax1.set_title("Total percentage of women in boards", pad=30)
ax2.set_title("Total percentage of women in boards IBEX35", pad=30)
ax3.set_title("Total percentage of women in boards > 500 M", pad=30)
ax4.set_title("Total percentage of women in boards < 500 M", pad=30)
plt.figlegend(labels=labels,loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white');
plt.suptitle('Work force distribution in Europe by gender and profession type (2022)')
# Out:
# Text(0.5, 0.98, 'Work force distribution in Europe by gender and profession type (2022)')

# %%
df = pd.DataFrame({'Women': [women_total_new['2017 %'][0], ibex_35_total_new['2017 %'][0], over_500_total_new['2017 %'][0], under_500_total_new['2017 %'][0]],
                   'Men': [women_total_new['2017 %'][1], ibex_35_total_new['2017 %'][1], over_500_total_new['2017 %'][1], under_500_total_new['2017 %'][1]]},
                  index=['TOTAL', 'IBEX35', 'OVER500', 'UNDER500'])

df2 = pd.DataFrame({'Women': [women_total_new['2021 %'][0], ibex_35_total_new['2021 %'][0], over_500_total_new['2021 %'][0], under_500_total_new['2021 %'][0]],
                   'Men': [women_total_new['2021 %'][1], ibex_35_total_new['2021 %'][1], over_500_total_new['2021 %'][1], under_500_total_new['2021 %'][1]]},
                  index=['TOTAL', 'IBEX35', 'OVER500', 'UNDER500'])

fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(30, 18), facecolor=c("grey1"))

df.plot(kind='barh', stacked=True, color=[c('red'), c('grey2')], ax=ax1)
ax.set_facecolor(c("grey1"))
plt.grid(color='white', linestyle='-.', linewidth=.2)

df2.plot(kind='barh', stacked=True, color=[c('red'), c('grey2')], ax=ax2)
ax.set_facecolor(c("grey1"))
plt.grid(visible=False)

plt.figlegend(labels=labels,loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white');
plt.legend([],[], frameon=False)

fig.text(0.5, 0.04, 'Percentage', ha='center');
fig.text(0.04, 0.5, '2017                                                               2021', va='center', rotation='vertical');
plt.suptitle('Women and men percentage in boards of largest companies, 2017 and 2021')
# Out:
# Text(0.5, 0.98, 'Women and men percentage in boards of largest companies, 2017 and 2021')

# %%
df = pd.DataFrame({'Women_2017': [women_total_new['2017 %'][0], ibex_35_total_new['2017 %'][0], over_500_total_new['2017 %'][0], under_500_total_new['2017 %'][0]],
                   'Women_2018': [0.199, 0.23913, 0.192, 0.169323],
                   'Women_2019': [0.231963, 0.275168, 0.219907, 0.197561],
                   'Women_2020': [0.261, 0.3126, 0.2488	, 0.2198],
                   'Women_2021': [0.2926, 0.342, 0.2817, 0.2519]},
                  index=['TOTAL', 'IBEX35', 'OVER500', 'UNDER500'])

df2 = pd.DataFrame({'Women': [women_total_new['2021 %'][0], ibex_35_total_new['2021 %'][0], over_500_total_new['2021 %'][0], under_500_total_new['2021 %'][0]],
                   'Men': [women_total_new['2021 %'][1], ibex_35_total_new['2021 %'][1], over_500_total_new['2021 %'][1], under_500_total_new['2021 %'][1]]},
                  index=['TOTAL', 'IBEX35', 'OVER500', 'UNDER500'])

fig, (ax1) = plt.subplots(nrows=1, figsize=(20, 10), facecolor=c("grey1"))
df.plot(kind='bar', color=['#c81200', '#eb3928', c('red'), '#df766b', '#e79289'], ax=ax1)
ax.set_facecolor(c("grey1"))

plt.grid(visible=False)

plt.figlegend(labels=labels,loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white');
plt.legend([],[], frameon=False)

fig.text(0.5, 0.04, 'Percentage', ha='center');
fig.text(0.04, 0.5, '2017                                                               2021', va='center', rotation='vertical');
plt.suptitle('Women and men percentage in boards of largest companies, 2017 and 2021')
# Out:
# Text(0.5, 0.98, 'Women and men percentage in boards of largest companies, 2017 and 2021')

# %%
women_total_growth = pd.read_csv('women_total_growth.csv')

# %%
women_total_growth['percentage_growth_2017_2021'] = percentage_change(women_total_growth['2017 %'],women_total_growth['2021 %'])    
women_total_growth
# Out:
#    Unnamed: 0  2017 %  2018 %    2019 %  2020 %  2021 %  \
# 0           0   0.189   0.199  0.231963   0.261  0.2926
#
#    percentage_growth_2017_2021
# 0                    54.814815

# %%
women_total_growth['percentage_growth_2020_2021'] = percentage_change(women_total_growth['2020 %'],women_total_growth['2021 %'])    
women_total_growth
# Out:
#    Unnamed: 0  2017 %  2018 %    2019 %  2020 %  2021 %  \
# 0           0   0.189   0.199  0.231963   0.261  0.2926
#
#    percentage_growth_2017_2021  percentage_growth_2020_2021
# 0                    54.814815                     12.10728

# %%
new_years =[2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030]

# %%
def future_value_estimate(amt, int):
    years=1
    future_value = amt*((1+(0.01*int)) ** years)
    return future_value

# %%
for year in new_years:
    year_label = year - 1
    year_lable_column = str(year_label)
    column_label = year_lable_column + ' ' + '%'
    value = future_value_estimate(women_total_growth[column_label][0], 12.10728	)
    women_total_growth[str(year) + ' ' + '%'] = value

# %%
women_total_growth_estimate = women_total_growth.drop(['Unnamed: 0', 'percentage_growth_2020_2021'], axis=1)
women_total_growth_estimate.columns = women_total_growth_estimate.columns.str.split(' ').str[0]
women_total_growth_estimate_dict = {'year' : women_total_growth_estimate.columns,
                                    'value': women_total_growth_estimate.loc[0, :].values.tolist()}
women_total_growth_estimate_dict_new = pd.DataFrame.from_dict(women_total_growth_estimate_dict)
women_total_growth_estimate_dict_new
# Out:
#                            year      value
# 0                          2017   0.189000
# 1                          2018   0.199000
# 2                          2019   0.231963
# 3                          2020   0.261000
# 4                          2021   0.292600
# 5   percentage_growth_2017_2021  54.814815
# 6                          2022   0.328026
# 7                          2023   0.367741
# 8                          2024   0.412264
# 9                          2025   0.462178
# 10                         2026   0.518136
# 11                         2027   0.580868
# 12                         2028   0.651195
# 13                         2029   0.730037
# 14                         2030   0.818425

# %%
for year in new_years:
    year_label = year - 1
    year_lable_column = str(year_label)
    column_label = year_lable_column + ' ' + '%'
    value = future_value_estimate(women_total_growth[column_label][0], 12.10728	)
    women_total_growth[str(year) + ' ' + '%'] = value

# %%
fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(15, 9))
ax.set_facecolor(c("grey1"))

colors = [c('red')]
sns.set_palette(sns.color_palette(colors))

sns.lineplot(x='year', y='value', 
             data=women_total_growth_estimate_dict_new, ci=300)

plt.scatter(x=13, y=0.5, color='r')

plt.legend(loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white', labels=['Women']);

plt.grid(color='white', linestyle='-.', linewidth=.4)
plt.title("Estimated growth of women percentage on boards largest companies Spain", pad=30)
# Out:
# Text(0.5, 1.0, 'Estimated growth of women percentage on boards largest companies Spain')

# %%
# fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(15, 9))
# ax.set_facecolor(c("grey1"))

# colors = [c('red')]
# sns.set_palette(sns.color_palette(colors))

# sns.lineplot(x='year', y='value', 
#              data=women_total_growth_estimate_dict_new, ci=300)
# plt.scatter(x=13, y=50, color='r')

# plt.legend(loc = 2, bbox_to_anchor = (1,1), prop={'size': 15}, facecolor=c('grey1'), edgecolor='white', labels=['Women']);
# plt.grid(color='white', linestyle='-.', linewidth=.4)
# plt.title("Estimated growth of women percentage on boards largest companies Spain", pad=30)

# %%
indeed_ratings_ibex35 = pd.read_csv('ibex_35_ratings_data.csv')
indeed_ratings_over500 = pd.read_csv('over_500_ratings_data.csv')
indeed_ratings_under500 = pd.read_csv('under_500_ratings_.csv')

# %%
indeed_ratings_ibex35.drop(columns=indeed_ratings_ibex35.columns[0], axis=1, inplace=True)
indeed_ratings_over500.drop(columns=indeed_ratings_ibex35.columns[0], axis=1, inplace=True)
indeed_ratings_under500.drop(columns=indeed_ratings_ibex35.columns[0], axis=1, inplace=True)

# %%
indeed_ratings_ibex35_valido = indeed_ratings_ibex35.iloc[:, [0, 1, 2, 3, 4, 5, 6, 7, 13]]

# %%
indeed_ratings_ibex35_valido_2018 = indeed_ratings_ibex35_valido.iloc[:, [0, 1, 2, 3, 8]]
indeed_ratings_ibex35_valido_2019 = indeed_ratings_ibex35_valido.iloc[:, [0, 1, 2, 4, 8]]
indeed_ratings_ibex35_valido_2020 = indeed_ratings_ibex35_valido.iloc[:, [0, 1, 2, 5, 8]]
indeed_ratings_ibex35_valido_2021 = indeed_ratings_ibex35_valido.iloc[:, [0, 1, 2, 6, 8]]
indeed_ratings_ibex35_valido_2022 = indeed_ratings_ibex35_valido.iloc[:, [0, 1, 2, 7, 8]]

# %%
indeed_ratings_ibex35_valido_2018.rename(columns={"2018": "Yearly rating"}, inplace=True)
indeed_ratings_ibex35_valido_2019.rename(columns={"2019": "Yearly rating"}, inplace=True)
indeed_ratings_ibex35_valido_2020.rename(columns={"2020": "Yearly rating"}, inplace=True)
indeed_ratings_ibex35_valido_2021.rename(columns={"2021": "Yearly rating"}, inplace=True)
indeed_ratings_ibex35_valido_2022.rename(columns={"2022": "Yearly rating"}, inplace=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
indeed_ratings_ibex35_valido_2018.rename(columns={"Company": "Name"}, inplace=True)
indeed_ratings_ibex35_valido_2019.rename(columns={"Company": "Name"}, inplace=True)
indeed_ratings_ibex35_valido_2020.rename(columns={"Company": "Name"}, inplace=True)
indeed_ratings_ibex35_valido_2021.rename(columns={"Company": "Name"}, inplace=True)
indeed_ratings_ibex35_valido_2022.rename(columns={"Company": "Name"}, inplace=True)

# %%
# indeed_ratings_ibex35_valido_2022['Year_rating'] = 2022
# indeed_ratings_ibex35_valido_2021['Year'] = 2021
# indeed_ratings_ibex35_valido_2020['Year'] = 2020
# indeed_ratings_ibex35_valido_2019['Year'] = 2019
# indeed_ratings_ibex35_valido_2018['Year'] = 2018

# %%
new_dataframe_ratings_ibex35 = pd.concat([indeed_ratings_ibex35_valido_2022, indeed_ratings_ibex35_valido_2021, indeed_ratings_ibex35_valido_2020, indeed_ratings_ibex35_valido_2019, indeed_ratings_ibex35_valido_2018])

# %%
women_index35_2021 = pd.read_csv('women_presence_board_ibex35_2021.csv')
women_index35_2020 = pd.read_csv('women_presence_board_ibex35_2020.csv')
women_index35_2019 = pd.read_csv('women_presence_board_ibex35_2019.csv')
women_index35_2018 = pd.read_csv('women_presence_board_ibex35_2018.csv')
women_index35_2017 = pd.read_csv('women_presence_board_ibex35_2017.csv')

# %%
women_index35_2021.drop(columns=women_index35_2021.columns[0], axis=1, inplace=True)
women_index35_2020.drop(columns=women_index35_2020.columns[0], axis=1, inplace=True)
women_index35_2019.drop(columns=women_index35_2019.columns[0], axis=1, inplace=True)
women_index35_2018.drop(columns=women_index35_2018.columns[0], axis=1, inplace=True)
women_index35_2017.drop(columns=women_index35_2017.columns[0], axis=1, inplace=True)

# %%
women_index35_2021 = women_index35_2021.iloc[:, [0, 1, 2, 3, 16, 17, 18]]
women_index35_2020 = women_index35_2020.iloc[:, [0, 1, 2, 3, 16, 17, 18]]
women_index35_2019 = women_index35_2019.iloc[:, [0, 1, 2, 3, 16, 17, 18]]
women_index35_2018 = women_index35_2018.iloc[:, [0, 1, 2, 3, 16, 17, 18]]
women_index35_2017 = women_index35_2017.iloc[:, [0, 1, 2, 3, 16, 17, 18]]

# %%
women_index35_2021['Year'] = 2021
women_index35_2020['Year'] = 2020
women_index35_2019['Year'] = 2019
women_index35_2018['Year'] = 2018
women_index35_2017['Year'] = 2017

# %%
new_dataframe_ibex35 = pd.concat([women_index35_2021, women_index35_2020, women_index35_2019, women_index35_2018, women_index35_2017])

# %%
indeed_ratings_ibex35.rename(columns={"Company": "Name"}, inplace=True)

# %%
ibex_35_merged_2018 = pd.merge(indeed_ratings_ibex35_valido_2018, women_index35_2018, on='Name')
ibex_35_merged_2019 = pd.merge(indeed_ratings_ibex35_valido_2019, women_index35_2019, on='Name')
ibex_35_merged_2020 = pd.merge(indeed_ratings_ibex35_valido_2020, women_index35_2020, on='Name')
ibex_35_merged_2021 = pd.merge(indeed_ratings_ibex35_valido_2021, women_index35_2021, on='Name')

# %%
fig, axes = plt.subplots(1, 4, figsize=(25,4))

sns.scatterplot(data = ibex_35_merged_2021, x = "rating", y = "% women board members", ax=axes[0])
sns.scatterplot(data = ibex_35_merged_2019, x = "rating", y = "% women board members", ax=axes[1])
sns.scatterplot(data = ibex_35_merged_2018, x = "rating", y = "% women board members", ax=axes[2])
sns.scatterplot(data = ibex_35_merged_2018, x = "rating", y = "% women board members", ax=axes[3])

plt.setp(axes, ylim=(0, 0.5));

# %%
fig, axes = plt.subplots(1, 4, figsize=(25,4))

sns.scatterplot(data = ibex_35_merged_2021, x = "salary satisfaction", y = "% women board members", ax=axes[0])
sns.scatterplot(data = ibex_35_merged_2019, x = "salary satisfaction", y = "% women board members", ax=axes[1])
sns.scatterplot(data = ibex_35_merged_2018, x = "salary satisfaction", y = "% women board members", ax=axes[2])
sns.scatterplot(data = ibex_35_merged_2018, x = "salary satisfaction", y = "% women board members", ax=axes[3])
# Out:
# <AxesSubplot:xlabel='salary satisfaction', ylabel='% women board members'>

# %%
fig, axes = plt.subplots(1, 4, figsize=(25,4))

sns.scatterplot(data = ibex_35_merged_2021, x = "ratings number", y = "% women board members", ax=axes[0])
sns.scatterplot(data = ibex_35_merged_2019, x = "ratings number", y = "% women board members", ax=axes[1])
sns.scatterplot(data = ibex_35_merged_2018, x = "ratings number", y = "% women board members", ax=axes[2])
sns.scatterplot(data = ibex_35_merged_2018, x = "ratings number", y = "% women board members", ax=axes[3])

plt.setp(axes, ylim=(0, 0.6));

# %%
fig, axes = plt.subplots(1, 4, figsize=(25,4))

sns.scatterplot(data = ibex_35_merged_2021, x = "Total board members", y = "% women board members", ax=axes[0])
sns.scatterplot(data = ibex_35_merged_2019, x = "Total board members", y = "% women board members", ax=axes[1])
sns.scatterplot(data = ibex_35_merged_2018, x = "Total board members", y = "% women board members", ax=axes[2])
sns.scatterplot(data = ibex_35_merged_2018, x = "Total board members", y = "% women board members", ax=axes[3])

plt.setp(axes, xlim=(5.5,18.5), ylim=(0, 0.6));

# %%
fig, axes = plt.subplots(1, 4, figsize=(25,4))

sns.scatterplot(data = ibex_35_merged_2021, x = "ratings number", y = "Total board members", ax=axes[0])
sns.scatterplot(data = ibex_35_merged_2019, x = "ratings number", y = "Total board members", ax=axes[1])
sns.scatterplot(data = ibex_35_merged_2018, x = "ratings number", y = "Total board members", ax=axes[2])
sns.scatterplot(data = ibex_35_merged_2018, x = "ratings number", y = "Total board members", ax=axes[3])

plt.setp(axes, ylim=(0, 19));

# %%
fig, axes = plt.subplots(1, 4, figsize=(25,4))

sns.scatterplot(data = ibex_35_merged_2021, x = "rating", y = "% total women key executives no members of the board", ax=axes[0]);
sns.scatterplot(data = ibex_35_merged_2019, x = "rating", y = "% total women key executives no members of the board", ax=axes[1]);
sns.scatterplot(data = ibex_35_merged_2018, x = "rating", y = "% total women key executives no members of the board", ax=axes[2]);
sns.scatterplot(data = ibex_35_merged_2018, x = "rating", y = "% total women key executives no members of the board", ax=axes[3]);

# plt.setp(axes, ylim=(0, 19));

# %%
fig, axes = plt.subplots(1, 4, figsize=(25,4))

sns.scatterplot(data = ibex_35_merged_2021, x = "% women board members", y = "% total women key executives no members of the board", ax=axes[0]);
sns.scatterplot(data = ibex_35_merged_2019, x = "% women board members", y = "% total women key executives no members of the board", ax=axes[1]);
sns.scatterplot(data = ibex_35_merged_2018, x = "% women board members", y = "% total women key executives no members of the board", ax=axes[2]);
sns.scatterplot(data = ibex_35_merged_2018, x = "% women board members", y = "% total women key executives no members of the board", ax=axes[3]);

# %%
fig, axes = plt.subplots(1, 4, figsize=(25,4), facecolor=c("grey1"))
ax.set_facecolor(c("grey1"))

sns.scatterplot(data = ibex_35_merged_2021, x = "rating", y = "% women board members", ax=axes[0])
sns.scatterplot(data = ibex_35_merged_2021, x = "% women board members", y = "salary satisfaction", ax=axes[2])
sns.scatterplot(data = ibex_35_merged_2021, x = "% women board members", y = "Total board members", ax=axes[3])
sns.scatterplot(data = ibex_35_merged_2021, x = "rating", y = "% total women key executives no members of the board", ax=axes[1]);

# %%
ax = sns.violinplot(y=ibex_35_merged_2021["% women board members"])

# %%
ibex_35_merged = pd.concat([ibex_35_merged_2018, ibex_35_merged_2019, ibex_35_merged_2020, ibex_35_merged_2021], ignore_index=True, axis=0)

# %%
# fig, ax = plt.subplots(figsize=(30,30))

sns.catplot(ax=ax, x="Year", y="Yearly rating", hue='Name', data=ibex_35_merged, kind='point', height=12, aspect=18/8.27)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(ax=ax, x="Year", y="% women board members", hue='Name', data=ibex_35_merged, kind='point', height=12, aspect=18/8.27)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try pointplot
#   warnings.warn(msg, UserWarning)

# %%
indicators_world_female_shares = pd.read_csv('indicators_world_female_shares.csv')

# %%
fig, axes = plt.subplots(1, 4, figsize=(25,4))

sns.scatterplot(data = indicators_world_female_shares, x = "Value", y = "Quality of support network", ax=axes[0])
sns.scatterplot(data = indicators_world_female_shares, x = "Value", y = "Educational Attainment", ax=axes[1])
sns.scatterplot(data = indicators_world_female_shares, x = "Value", y = "Years in education", ax=axes[2])
sns.scatterplot(data = indicators_world_female_shares, x = "Value", y = "Life satisfaction", ax=axes[3])

# plt.setp(axes, ylim=(0, 0.5));
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Life satisfaction'>

# %%
fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(13, 8))
ax.set_facecolor(c("grey1"))

sns.scatterplot(data = indicators_world_female_shares, x = "Value", y = "Life satisfaction", s=90)
plt.grid(color='white', linestyle='-.', linewidth=.4)

# %%
indicators_world_female_shares['Value'].corr(indicators_world_female_shares['Life satisfaction'])
# Out:
# 0.6988539307659697

# %%
fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(13, 8))
ax.set_facecolor(c("grey1"))
colors = ['#e79289', '#eb3928', c('red'), '#d13a2d', '#df766b', '#c81200', '#c81200']
sns.set_palette(sns.color_palette(colors))
ax = sns.violinplot(y=ibex_35_merged_2021["% women board members"])
plt.grid(visible=False)

# %%
corr = indicators_world_female_shares.corr()
fig, ax = plt.subplots(facecolor=c("grey1"), figsize=(13, 8))
ax.set_facecolor(c("grey1"))
colors = ['#e79289', '#eb3928', c('red'), '#d13a2d', '#df766b', '#c81200', '#c81200']
sns.set_palette(sns.color_palette('dark:salmon_r'))
sns.heatmap(corr, cmap='Reds', annot=True)
# Out:
# <AxesSubplot:>

# %%
indicators_world_female_shares
# Out:
#     Unnamed: 0          Country  Quality of support network  \
# 0            0        Australia                        93.0
# 1            1          Austria                        92.0
# 2            2          Belgium                        90.0
# 3            3           Canada                        93.0
# 4            4   Czech Republic                        96.0
# 5            5          Denmark                        95.0
# 6            6          Finland                        96.0
# 7            7           France                        94.0
# 8            8          Germany                        90.0
# 9            9           Greece                        78.0
# 10          10          Hungary                        94.0
# 11          11          Iceland                        98.0
# 12          12          Ireland                        96.0
# 13          13            Italy                        89.0
# 14          14            Korea                        80.0
# ...

# %%
# test_indrek = pd.read_csv('../eda_junio_22/data/02_women_boards_worldwide/paises_seleccionados_board_world_percentage.csv')
